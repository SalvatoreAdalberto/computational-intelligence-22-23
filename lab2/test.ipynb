# %%
import numpy as np

# %%
import random
from collections import namedtuple
from matplotlib import pyplot as plt


def GA_set_covering(N):

    def problem(N, seed=None):
        random.seed(seed)
        return [
            list(set(random.randint(0, N - 1)
                 for n in range(random.randint(N // 5, N // 2))))
            for n in range(random.randint(N, N * 5))
        ]

    def evaluate_weight( genome):
        indexes = [i for i, x in enumerate(genome) if x == 1]
        all_elements = [element for sublist in [generated_problem[x] for x in indexes] for element in sublist]
        return len(all_elements)

    def is_solving( genome):
        indexes = [i for i, x in enumerate(genome) if x == 1]
        all_elements = [element for sublist in [generated_problem[x] for x in indexes] for element in sublist]
        coverage = len(set(all_elements))
        return coverage == N

    def evaluate_fitness( genome):
        # fitness considers how many numbers are already covered and the weight of the solution
        indexes = [i for i, x in enumerate(genome) if x == 1]
        all_elements = [element for sublist in [generated_problem[x]
                                                for x in indexes] for element in sublist]
        weight = len(all_elements)
        coverage = len(set(all_elements))
        boost_for_correct_solution = N/2 if coverage == N else 0
        #return boost_for_correct_solution + 0.3*coverage - 0.1*weight
        return (-(N-coverage), -weight)

    def tournament( population, tournament_size=2):
        return max(random.choices(population, k=tournament_size), key=lambda i: i.fitness)

    def cross_over( g1, g2):
        cut = random.randint(0, PROBLEM_SIZE)
        return g1[:cut] + g2[cut:]

    def mutation( g):
        point = random.randint(0, PROBLEM_SIZE-1)
        return g[:point] + (1 - g[point],) + g[point + 1:]
    
    def plot_performance(self):
        off_line = [max(f[1] for f in fitness_log if f[0] == x) / (x + 1)
                    for x in range(NUM_GENERATIONS)]
        on_line = [max(f[1] for f in fitness_log if f[0] <= x) / (x + 1)
                   for x in range(NUM_GENERATIONS)]
        gen_best = [max(f[1] for f in fitness_log if f[0] == x)
                    for x in range(NUM_GENERATIONS)]

        plt.figure(figsize=(15, 6))
        plt.scatter([x for x, _ in fitness_log], [
                    y for _, y in fitness_log], marker=".")
        plt.plot([x for x, _ in enumerate(gen_best)],
                 [y for _, y in enumerate(gen_best)])
        plt.plot([x for x, _ in enumerate(on_line)],
                 [y for _, y in enumerate(on_line)])
        plt.plot([x for x, _ in enumerate(off_line)],
                 [y for _, y in enumerate(off_line)])


    Individual = namedtuple("Individual", ["genome", "fitness"])
    generated_problem = problem(N)
    PROBLEM_SIZE = len(generated_problem)
    POPULATION_SIZE = 30
    NUM_GENERATIONS = 300
    OFFSPRING_SIZE = 80
    population = list()
    for genome in [tuple([random.choice([1, 0]) for _ in range(PROBLEM_SIZE)]) for _ in range(POPULATION_SIZE)]:
        population.append(Individual(genome, evaluate_fitness(genome)))
    fitness_log = [(0, i.fitness) for i in population]

    for g in range(NUM_GENERATIONS):
        offspring = list()
        lr = 0.2 if g < 200 else 0.7
        for i in range(OFFSPRING_SIZE):
            if random.random() < lr:
                p = tournament(population)
                o = mutation(p.genome)
            else:
                p1 = tournament(population)
                p2 = tournament(population)
                o = cross_over(p1.genome, p2.genome)
            f = evaluate_fitness(o)
            fitness_log.append((g + 1, f))
            offspring.append(Individual(o, f))
        population += offspring
        population = sorted(population, key=lambda i: i.fitness, reverse=True)[
            :POPULATION_SIZE]
        print(f"gen: {g}, fitness: {population[0].fitness}, weight: {evaluate_weight(population[0].genome)}, solves? {is_solving(population[0].genome)}")
    return [population[0].fitness, evaluate_weight(population[0].genome)]

# %%
ts = np.zeros((2, 2))

for i in range(0,2):
    ts[i]+=(GA_set_covering(500))

f_mean, w_mean = ts.mean(axis=0)
print(f"f_mean: {f_mean}, w_mean: {w_mean}")
# Out:
# gen: 0, fitness: -7702.400000000001, weight: 81024, solves? True
# gen: 1, fitness: -7566.200000000001, weight: 79662, solves? True
# gen: 2, fitness: -7502.8, weight: 79028, solves? True
# gen: 3, fitness: -7254.700000000001, weight: 76547, solves? True
# gen: 4, fitness: -7236.3, weight: 76363, solves? True
# gen: 5, fitness: -7075.8, weight: 74758, solves? True
# gen: 6, fitness: -7016.1, weight: 74161, solves? True
# gen: 7, fitness: -6936.6, weight: 73366, solves? True
# gen: 8, fitness: -6915.5, weight: 73155, solves? True
# gen: 9, fitness: -6897.6, weight: 72976, solves? True
# gen: 10, fitness: -6863.6, weight: 72636, solves? True
# gen: 11, fitness: -6795.700000000001, weight: 71957, solves? True
# gen: 12, fitness: -6761.700000000001, weight: 71617, solves? True
# gen: 13, fitness: -6758.8, weight: 71588, solves? True
# gen: 14, fitness: -6741.8, weight: 71418, solves? True
# gen: 15, fitness: -6728.900000000001, weight: 71289, solves? True
# gen: 16, fitness: -6724.1, weight: 71241, solves? True
# gen: 17, fitness: -6706.0, weight: 71060, solves? True
# gen: 18, fitness: -6689.400000000001, weight: 70894, solves? True
# gen: 19, fitness: -6671.5, weight: 70715, solves? True
# gen: 20, fitness: -6655.700000000001, weight: 70557, solves? True
# gen: 21, fitness: -6638.1, weight: 70381, solves? True
# gen: 22, fitness: -6623.1, weight: 70231, solves? True
# gen: 23, fitness: -6604.400000000001, weight: 70044, solves? True
# gen: 24, fitness: -6573.1, weight: 69731, solves? True
# gen: 25, fitness: -6561.6, weight: 69616, solves? True
# gen: 26, fitness: -6559.5, weight: 69595, solves? True
# gen: 27, fitness: -6542.900000000001, weight: 69429, solves? True
# gen: 28, fitness: -6524.900000000001, weight: 69249, solves? True
# gen: 29, fitness: -6503.900000000001, weight: 69039, solves? True
# gen: 30, fitness: -6485.5, weight: 68855, solves? True
# gen: 31, fitness: -6461.400000000001, weight: 68614, solves? True
# gen: 32, fitness: -6417.700000000001, weight: 68177, solves? True
# gen: 33, fitness: -6415.3, weight: 68153, solves? True
# gen: 34, fitness: -6397.0, weight: 67970, solves? True
# gen: 35, fitness: -6358.900000000001, weight: 67589, solves? True
# gen: 36, fitness: -6315.5, weight: 67155, solves? True
# gen: 37, fitness: -6315.5, weight: 67155, solves? True
# gen: 38, fitness: -6302.400000000001, weight: 67024, solves? True
# gen: 39, fitness: -6289.3, weight: 66893, solves? True
# gen: 40, fitness: -6284.6, weight: 66846, solves? True
# gen: 36, fitness: -12595.900000000001, weight: 129959, solves? True
# gen: 37, fitness: -12588.2, weight: 129882, solves? True
# gen: 38, fitness: -12555.1, weight: 129551, solves? True
# gen: 39, fitness: -12544.1, weight: 129441, solves? True
# gen: 40, fitness: -12536.5, weight: 129365, solves? True
# gen: 41, fitness: -12513.0, weight: 129130, solves? True
# gen: 42, fitness: -12496.0, weight: 128960, solves? True
# gen: 43, fitness: -12478.1, weight: 128781, solves? True
# gen: 44, fitness: -12445.1, weight: 128451, solves? True
# gen: 45, fitness: -12426.7, weight: 128267, solves? True
# gen: 46, fitness: -12407.0, weight: 128070, solves? True
# gen: 47, fitness: -12389.900000000001, weight: 127899, solves? True
# gen: 48, fitness: -12377.900000000001, weight: 127779, solves? True
# gen: 49, fitness: -12351.0, weight: 127510, solves? True
# gen: 50, fitness: -12324.2, weight: 127242, solves? True
# gen: 51, fitness: -12304.5, weight: 127045, solves? True
# gen: 52, fitness: -12303.7, weight: 127037, solves? True
# gen: 53, fitness: -12287.1, weight: 126871, solves? True
# gen: 54, fitness: -12272.0, weight: 126720, solves? True
# gen: 55, fitness: -12257.7, weight: 126577, solves? True
# gen: 56, fitness: -12241.7, weight: 126417, solves? True
# gen: 57, fitness: -12216.6, weight: 126166, solves? True
# gen: 58, fitness: -12200.6, weight: 126006, solves? True
# gen: 59, fitness: -12183.0, weight: 125830, solves? True
# gen: 60, fitness: -12163.6, weight: 125636, solves? True
# gen: 61, fitness: -12142.0, weight: 125420, solves? True
# gen: 62, fitness: -12128.1, weight: 125281, solves? True
# gen: 63, fitness: -12110.900000000001, weight: 125109, solves? True
# gen: 64, fitness: -12082.7, weight: 124827, solves? True
# gen: 65, fitness: -12048.0, weight: 124480, solves? True
# gen: 66, fitness: -11997.2, weight: 123972, solves? True
# gen: 67, fitness: -11982.5, weight: 123825, solves? True
# gen: 68, fitness: -11965.400000000001, weight: 123654, solves? True
# gen: 69, fitness: -11945.5, weight: 123455, solves? True
# gen: 70, fitness: -11932.900000000001, weight: 123329, solves? True
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [36], line 4
#       1 ts = np.zeros((2, 2))
#       3 for i in range(0,2):
# ----> 4     ts[i]+=(GA_set_covering(500))
#       6 f_mean, w_mean = ts.mean(axis=0)
#       7 print(f"f_mean: {f_mean}, w_mean: {w_mean}")
#
# Cell In [35], line 89, in GA_set_covering(N)
#      87     p2 = tournament(population)
#      88     o = cross_over(p1.genome, p2.genome)
# ---> 89 f = evaluate_fitness(o)
#      90 fitness_log.append((g + 1, f))
#      91 offspring.append(Individual(o, f))
#
# Cell In [35], line 33, in GA_set_covering.<locals>.evaluate_fitness(genome)
#      30 all_elements = [element for sublist in [generated_problem[x]
#      31                                         for x in indexes] for element in sublist]
#      32 weight = len(all_elements)
# ---> 33 coverage = len(set(all_elements))
#      34 boost_for_correct_solution = N/2 if coverage == N else 0
#      35 return boost_for_correct_solution + 0.3*coverage - 0.1*weight
#
# KeyboardInterrupt:
